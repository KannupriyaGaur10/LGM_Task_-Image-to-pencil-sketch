# %% [markdown]
# # Image to Pencil Sketch with Python

# %% [markdown]
# # Import the required libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the Image

# %%
picture = cv2.imread(r"C:\Users\Kannupriya Gaur\OneDrive\Desktop\horse.jpg")
plt.axis(False)
plt.imshow(picture)
plt.show()

# %% [markdown]
# # Convert the Image into RGB colour format

# %%
picture1 = cv2.cvtColor(picture, cv2.COLOR_BGR2RGB)
plt.imshow(picture1)
plt.axis(False)
plt.show()

# %% [markdown]
# # Convert the image into grey scale format

# %%
picture2 = cv2.cvtColor(picture1, cv2.COLOR_BGR2GRAY)
plt.imshow(picture2)
plt.axis(False)
plt.show()

# %% [markdown]
# # Convert the image into inverted format

# %%
picture3 = cv2.bitwise_not(picture2)
plt.imshow(pic_3)
plt.axis(False)
plt.show()

# %% [markdown]
# # Convert the image into inverted blurr format

# %%
picture4 = cv2.GaussianBlur(pic_3, (51,51), sigmaX=0, sigmaY=0)
plt.imshow(picture4)
plt.axis(False)
plt.show()

# %% [markdown]
# # Converting image into blurred format

# %%
picture5 = cv2.bitwise_not(picture4)
plt.imshow(picture5)
plt.axis(False)
plt.show()

# %% [markdown]
# # Dividing the blurr image and grey scale format image

# %%
picture6 = cv2.divide(picture2,picture5 , scale=250.0)
plt.imshow(picture6)
plt.axis(False)
plt.show()

# %% [markdown]
# # Converting the image into pencil sketch format

# %%
plt.figure(figsize = (12,8))
sketch = cv2.cvtColor(picture6, cv2.COLOR_RGB2BGR)
plt.imshow(sketch)
plt.axis(False)
plt.show()

# %% [markdown]
# # Save the image into the device

# %%
cv2.imwrite ("pencil_sketch.jpg",sketch )
# Out:
# True
